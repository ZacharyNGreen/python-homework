# %%
from pathlib import Path
import csv


# Initialize variables

#print(f"Current Working Directory: {Path.cwd()}")
csvpath = Path("./Resources/budget_data.csv")
total_months = 0
total_pnl = 0
avg_change = 0
total_change = 0

max_profit_change = 0
max_profit_change_mth = ""

min_profit_change = 0
min_profit_change_mth = ""


profit_change_list = []

with open(csvpath, "r") as csvfile:
    
    #print(type(csvfile))
    csvreader = csv.reader(csvfile, delimiter=",")
    #print(type(csvreader))
    header = next(csvreader)
    for row in csvreader:
        
        #create profit change entries for each month
        if total_months ==0:
            profit_entry=[row[0],0]
        else:
            profit_entry=[row[0],int(row[1])-prior_month_pnl]
        
        #Calculate number of months and total PnL
        total_months+=1
        total_pnl+=int(row[1])
        
        #save this months pnl for use in next months change calculation
        prior_month_pnl=int(row[1])
        
        #add profit change entries to the list of lists
        profit_change_list.append(profit_entry)
        
    #find maximum profit change
    for entry in profit_change_list:
        if max_profit_change_mth =="":
            max_profit_change_mth = entry[0]
            max_profit_change = entry[1]
        elif entry[1] > max_profit_change:
            max_profit_change_mth = entry[0]
            max_profit_change = entry[1]
        
        if min_profit_change_mth=="":
            min_profit_change_mth= entry[0]
            min_profit_change= entry[1]
        elif entry[1]< min_profit_change:
            min_profit_change_mth = entry[0]
            min_profit_change = entry[1]
    
    #calculate total change in profits for use in avg. profit change calculation
        total_change+=entry[1]
    
print("Financial Analysis")
print("----------------------------")
print(f"Total Months: {total_months}")
print(f"Total: ${total_pnl}")
print(f"Average_Change: ${round(total_change/(total_months-1),2)}")
#print(profit_change_list)
print(f"Greatest Increase in Profits: {max_profit_change_mth} $({max_profit_change})")
print(f"Greatest Increase in Profits: {min_profit_change_mth} $({min_profit_change})")

output_path=Path("output.txt")

with open(output_path,"w") as file:
    file.write("Financial Analysis\n")
    file.write("---------------------------\n")
    file.write(f"Total Months: {total_months}\n")
    file.write(f"Total: ${total_pnl}\n")
    file.write(f"Average_Change: ${round(total_change/(total_months-1),2)}\n")
    file.write(f"Greatest Increase in Profits: {max_profit_change_mth} $({max_profit_change})\n")
    file.write(f"Greatest Increase in Profits: {min_profit_change_mth} $({min_profit_change})\n")
# Out:
# Financial Analysis
# ----------------------------
# Total Months: 86
# Total: $38382578
# Average_Change: $-2315.12
# Greatest Increase in Profits: Feb-2012 $(1926159)
# Greatest Increase in Profits: Sep-2013 $(-2196167)
